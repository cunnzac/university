# %% [markdown]
# # **Section 1** (Weeks 1 & 2)
# ---

# %% [markdown]
# #### Variables

# %% [markdown]
# #### Data Types

# %%
mylist = []
mytuple = ()

# %% [markdown]
# #### Operators

# %% [markdown]
# #### Conditional Logic

# %% [markdown]
# # **Section 2** (Week 3)
# ---

# %% [markdown]
# #### Sets

# %% [markdown]
# #### Dictionaries

# %% [markdown]
# #### Stacks

# %% [markdown]
# #### Queues

# %% [markdown]
# #### Deques

# %% [markdown]
# #### Linked Lists

# %% [markdown]
# # **Section 3** (Weeks 4, 5, & 6)
# ---

# %% [markdown]
# #### Bubble Sort

# %%
"""pseudocode

array = [2, 7, 4, 8, 6]

passes = len(array) - 1

array[0:i]

for each item in the array
check the item and its neighbor
if needed, swap
so maybe use something like
x = array[n]
y = array[n+1]
if x > y:
    x, y = y, x
then the array slice shrinks by 1
repeat until i is 0


"""

# %% [markdown]
# #### Selection Sort

# %% [markdown]
# #### Insertion Sort
# https://www.hackerearth.com/practice/algorithms/sorting/insertion-sort/visualize/

# %% [markdown]
# #### Merge Sort

# %% [markdown]
# #### Quick Sort

# %% [markdown]
# # **Section 4** (Weeks 7 & 8)
# ---

# %% [markdown]
# #### Recursion

# %% [markdown]
# #### The Call Stack

# %% [markdown]
# #### Factorial

# %% [markdown]
# #### Sum of Natural Numbers

# %% [markdown]
# #### Power (a^b)

# %% [markdown]
# #### Reverse a String

# %% [markdown]
# #### Count Digits (non-negative int)

# %% [markdown]
# #### Common Pitfalls & Debugging Tips

# %% [markdown]
# #### Fibonacci (Naive Recursion)

# %% [markdown]
# #### Memoization Preview (Performance)

# %% [markdown]
# #### Euclidean Algorithm

# %% [markdown]
# #### Recursive Quick Sort (with Lomuto Partition)

# %% [markdown]
# #### Recursive vs Iterative Merge Sort
